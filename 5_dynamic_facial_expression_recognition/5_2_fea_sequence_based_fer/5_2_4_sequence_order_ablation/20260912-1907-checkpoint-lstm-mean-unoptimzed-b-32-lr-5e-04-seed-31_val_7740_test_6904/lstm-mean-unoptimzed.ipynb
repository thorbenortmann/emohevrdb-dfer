# %% [markdown]
# # Dynamic Facial Expression Recognition with Facial Expression Activations

# %%
# Set up notebook
name_of_this_notebook = 'lstm-mean-unoptimzed.ipynb'

BATCH_SIZE = 32
LR = 5e-4
SEED = 31

experiment_name = f'{name_of_this_notebook[:-6]}-b-{BATCH_SIZE}-lr-{LR:.0e}-seed-{SEED}'

# %%
import re
import ipykernel.iostream

TF_LOG_FILTER_PATTERNS = [
    r'ptx\d+.*is not a recognized feature for this target',
    r'is not a recognized feature for this target \(ignoring feature\)',
    r'\(ignoring feature\)',
    r'successful NUMA node read from SysFS had negative value \(-1\)',
    r'gpu_timer\.cc:114\] Skipping the delay kernel, measurement accuracy will be reduced',
]

KERAS_PROGRESS_PATTERNS = [
    r'ms/step',
    r's/step',
    r'ETA:',
    r'\d+/\d+ \[',   # 12/64 [===>...]
]

_original_write = ipykernel.iostream.OutStream.write

def _filtered_write(self, msg, *args, **kwargs):
    text = str(msg)

    if any(re.search(p, text) for p in KERAS_PROGRESS_PATTERNS):
        _original_write(self, text, *args, **kwargs)
        return

    buf = getattr(self, '_tf_log_filter_buf', '')
    buf += text

    if '\n' not in buf:
        setattr(self, '_tf_log_filter_buf', buf)
        return

    lines = buf.splitlines(keepends=True)
    if not buf.endswith('\n'):
        incomplete = lines.pop()
    else:
        incomplete = ''

    for line in lines:
        if any(re.search(p, line) for p in TF_LOG_FILTER_PATTERNS):
            continue
        _original_write(self, line, *args, **kwargs)

    setattr(self, '_tf_log_filter_buf', incomplete)

ipykernel.iostream.OutStream.write = _filtered_write

print('Notebook log filter installed (targeted, keeps Keras steps).')
# Out:
# Notebook log filter installed (targeted, keeps Keras steps).

# %%
# import keras

# keras.mixed_precision.set_global_policy('mixed_float16')

# %%
# Ensure Determinism
import random
import numpy as np
import tensorflow as tf
import keras


random.seed(SEED)
np.random.seed(SEED)
keras.utils.set_random_seed(SEED)
tf.random.set_seed(SEED)
tf.config.experimental.enable_op_determinism()
# Out:
# 2026-09-12 19:06:58.819804: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-09-12 19:06:58.828542: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8473] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-09-12 19:06:58.831302: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1471] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Ensure GPU works as expected
print('TensorFlow Version:', tf.__version__, ';', 'Keras Version:', keras.__version__)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f'Number of GPUs detected: {len(gpus)}')
    for gpu in gpus:
        device_details = tf.config.experimental.get_device_details(gpu)
        print(f'Physical Device: {gpu.name}')
        print(f'Name: {device_details['device_name']}')
        print(f'Compute Capability: {device_details['compute_capability']}')
else:
    print('No GPUs were detected.')
# Out:
# TensorFlow Version: 2.17.0 ; Keras Version: 3.12.0
# Number of GPUs detected: 1
# Physical Device: /physical_device:GPU:0
# Name: NVIDIA GeForce RTX 5090
# Compute Capability: (12, 0)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR

# %% [markdown]
# ## Prepare Data

# %%
from pathlib import Path
import pandas as pd

dataset_path = Path(r'/workspace/datasets/emoji-hero-vr-db-dfea-as-csv')

train_df = pd.read_csv(str(dataset_path / 'training_set.csv'))
print('train_df.shape:', train_df.shape)
val_df = pd.read_csv(str(dataset_path / 'validation_set.csv'))
print('val_df.shape:', val_df.shape)
test_df = pd.read_csv(str(dataset_path / 'test_set.csv'))
print('test_df.shape:', test_df.shape)
print('Columns:', test_df.columns)
# Out:
# train_df.shape: (28920, 66)
# val_df.shape: (11550, 66)
# test_df.shape: (11340, 66)
# Columns: Index(['sequence_id', 'timestamp', 'BrowLowererL', 'BrowLowererR',
#        'CheekPuffL', 'CheekPuffR', 'CheekRaiserL', 'CheekRaiserR',
#        'CheekSuckL', 'CheekSuckR', 'ChinRaiserB', 'ChinRaiserT', 'DimplerL',
#        'DimplerR', 'EyesClosedL', 'EyesClosedR', 'EyesLookDownL',
#        'EyesLookDownR', 'EyesLookLeftL', 'EyesLookLeftR', 'EyesLookRightL',
#        'EyesLookRightR', 'EyesLookUpL', 'EyesLookUpR', 'InnerBrowRaiserL',
#        'InnerBrowRaiserR', 'JawDrop', 'JawSidewaysLeft', 'JawSidewaysRight',
#        'JawThrust', 'LidTightenerL', 'LidTightenerR', 'LipCornerDepressorL',
#        'LipCornerDepressorR', 'LipCornerPullerL', 'LipCornerPullerR',
#        'LipFunnelerLB', 'LipFunnelerLT', 'LipFunnelerRB', 'LipFunnelerRT',
#        'LipPressorL', 'LipPressorR', 'LipPuckerL', 'LipPuckerR',
#        'LipStretcherL', 'LipStretcherR', 'LipSuckLB', 'LipSuckLT', 'LipSuckRB',
#        'LipSuckRT', 'LipTightenerL', 'LipTightenerR', 'LipsToward',
#        'LowerLipDepressorL', 'LowerLipDepressorR', 'MouthLeft', 'MouthRight',
#        'NoseWrinklerL', 'NoseWrinklerR', 'OuterBrowRaiserL',
#        'OuterBrowRaiserR', 'UpperLidRaiserL', 'UpperLidRaiserR',
#        'UpperLipRaiserL', 'UpperLipRaiserR', 'Label'],
#       dtype='object')

# %%
def prepare_data(df):
    grouped_by_sequence = df.groupby('sequence_id')

    sequences = []
    labels = []

    for sequence_id, group in grouped_by_sequence:
        sorted_group = group.sort_values(by='timestamp')
        sequences.append(sorted_group.iloc[:, 2:-1].values)  # Select all feature columns
        labels.append(sorted_group.iloc[0, -1])  # Select one label per group

    X = np.array(sequences)
    y = np.array(labels)
    return X, y


X_train_ordered, y_train = prepare_data(train_df)
X_val_ordered, y_val = prepare_data(val_df)
X_test_ordered, y_test = prepare_data(test_df)

# %% [markdown]
# ### Mean each sequence for sequence ablation

# %%
X_train = np.mean(X_train_ordered, axis=1)
X_val = np.mean(X_val_ordered, axis=1)
X_test = np.mean(X_test_ordered, axis=1)

# %% [markdown]
# ### Create tf.data.Datasets

# %%
def create_dataset(X, y, batch_size, reshuffle_each_iteration):
    dataset = tf.data.Dataset.from_tensor_slices((X, y))
    dataset = dataset.shuffle(len(X), seed=SEED, reshuffle_each_iteration=reshuffle_each_iteration).batch(batch_size)
    return dataset


train_dataset = create_dataset(X_train, y_train, BATCH_SIZE, True)
val_dataset = create_dataset(X_val, y_val, BATCH_SIZE, False)
test_dataset = create_dataset(X_test, y_test, BATCH_SIZE, False)

# %% [markdown]
# ### Prepare Class Frequencies for Loss Function

# %%
id_to_emotion = {
    0: 'Anger',
    1: 'Disgust',
    2: 'Fear',
    3: 'Happiness',
    4: 'Neutral',
    5: 'Sadness',
    6: 'Surprise',
}

class_frequencies = train_df['Label'].value_counts().sort_index()
print(f'--- Training Set Class Frequencies ---')
for class_id, frequency in class_frequencies.items():
    print(f'{class_id} - {id_to_emotion[class_id]:<9} : {frequency:>8}')


def scaled_inverse_freq_weights(counts: pd.Series) -> dict[int, float]:
    inv = 1.0 / counts
    # Scale so that the center is 1
    w = inv * (len(counts) / inv.sum())
    return {int(k): float(v) for k, v in w.items()}

class_weights = scaled_inverse_freq_weights(class_frequencies)
print(f'\nClass Weights:\n {class_weights}')
# Out:
# --- Training Set Class Frequencies ---
# 0 - Anger     :     1980
# 1 - Disgust   :     3060
# 2 - Fear      :     3150
# 3 - Happiness :     5730
# 4 - Neutral   :     5910
# 5 - Sadness   :     3930
# 6 - Surprise  :     5160
#
# Class Weights:
#  {0: 1.8211414828477057, 1: 1.1783856653720448, 2: 1.1447175035042723, 3: 0.6292949626594166, 4: 0.6101286186190283, 5: 0.9175216631141113, 6: 0.6988101038834219}

# %% [markdown]
# ## Define Network Architecture

# %%
from keras.layers import Input, Dense, Dropout, LSTM, Normalization, SpatialDropout1D, TimeDistributed
from keras.models import Model

norm = Normalization(axis=-1, name='norm_in')
# Use same normalization statistics as the ordered model
norm.adapt(X_train_ordered.reshape(-1, X_train_ordered.shape[-1]))

fea_input = Input(shape=(63,), name='fea_input')
x = norm(fea_input)
x = Dropout(0.25, name='fea_dropout_0')(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.2, name='fea_dropout_1')(x)
# x = Dense(128, activation='relu')(x)
# x = Dropout(0.2, name='fea_dropout_2')(x)
# x = Dense(64, activation='relu')(x)
# x = Dropout(0.4, name='fea_dropout_3')(x)
fau_output = Dense(len(id_to_emotion), activation='softmax')(x)

fea_model = Model(inputs=fea_input, outputs=fau_output)
fea_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ fea_input (InputLayer)          │ (None, 63)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ norm_in (Normalization)         │ (None, 63)             │           127 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fea_dropout_0 (Dropout)         │ (None, 63)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │         8,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fea_dropout_1 (Dropout)         │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,222 (36.03 KB)
#  Trainable params: 9,095 (35.53 KB)
#  Non-trainable params: 127 (512.00 B)

# %% [markdown]
# ## Train the Network

# %%
from datetime import datetime
from keras.optimizers import Adam
from keras.callbacks import CSVLogger, ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

optimizer = Adam(learning_rate=LR)

timestamp = datetime.now().strftime("%Y%m%d-%H%M")
checkpoint_dir = Path(f'{timestamp}-checkpoint-{experiment_name}')
checkpoint_dir.mkdir(parents=True, exist_ok=True)
best_model_path = f'{checkpoint_dir / "fea_model"}.keras'

model_checkpoint_callback = ModelCheckpoint(filepath=best_model_path,
                                            save_weights_only=False,
                                            monitor='val_loss',
                                            mode='min',
                                            save_best_only=True)

early_stopping_callback = EarlyStopping(monitor='val_loss', mode='min', patience=12, restore_best_weights=True)
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', mode='min', factor=0.5, patience=3, min_lr=1e-6)
csv_logger = CSVLogger(str(checkpoint_dir / 'training_log.csv'), append=False)
callbacks = [model_checkpoint_callback, early_stopping_callback, reduce_lr_callback]

fea_model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = fea_model.fit(train_dataset,
                        validation_data=val_dataset,
                        class_weight=class_weights,
                        callbacks=callbacks,
                        epochs=200)
# Out:
# Epoch 1/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2687 - loss: 1.7165 - val_accuracy: 0.4987 - val_loss: 1.5458 - learning_rate: 5.0000e-04
# Epoch 2/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5446 - loss: 1.3034 - val_accuracy: 0.6156 - val_loss: 1.1948 - learning_rate: 5.0000e-04
# Epoch 3/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6359 - loss: 1.1290 - val_accuracy: 0.6753 - val_loss: 1.0246 - learning_rate: 5.0000e-04
# Epoch 4/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6680 - loss: 0.9954 - val_accuracy: 0.7039 - val_loss: 0.9127 - learning_rate: 5.0000e-04
# Epoch 5/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6878 - loss: 0.9386 - val_accuracy: 0.7247 - val_loss: 0.8492 - learning_rate: 5.0000e-04
# Epoch 6/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7106 - loss: 0.8889 - val_accuracy: 0.7143 - val_loss: 0.8014 - learning_rate: 5.0000e-04
# Epoch 7/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7054 - loss: 0.8532 - val_accuracy: 0.7221 - val_loss: 0.7736 - learning_rate: 5.0000e-04
# Epoch 8/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7147 - loss: 0.8131 - val_accuracy: 0.7377 - val_loss: 0.7467 - learning_rate: 5.0000e-04
# Epoch 9/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7334 - loss: 0.7661 - val_accuracy: 0.7455 - val_loss: 0.7220 - learning_rate: 5.0000e-04
# Epoch 10/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7261 - loss: 0.7705 - val_accuracy: 0.7506 - val_loss: 0.7085 - learning_rate: 5.0000e-04
# Epoch 11/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7324 - loss: 0.7339 - val_accuracy: 0.7584 - val_loss: 0.6929 - learning_rate: 5.0000e-04
# Epoch 12/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7479 - loss: 0.7204 - val_accuracy: 0.7636 - val_loss: 0.6850 - learning_rate: 5.0000e-04
# Epoch 13/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7396 - loss: 0.7009 - val_accuracy: 0.7532 - val_loss: 0.6807 - learning_rate: 5.0000e-04
# Epoch 14/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7490 - loss: 0.6757 - val_accuracy: 0.7610 - val_loss: 0.6697 - learning_rate: 5.0000e-04
# Epoch 15/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7552 - loss: 0.6918 - val_accuracy: 0.7662 - val_loss: 0.6639 - learning_rate: 5.0000e-04
# Epoch 16/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7583 - loss: 0.6852 - val_accuracy: 0.7558 - val_loss: 0.6661 - learning_rate: 5.0000e-04
# Epoch 17/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7562 - loss: 0.6627 - val_accuracy: 0.7610 - val_loss: 0.6647 - learning_rate: 5.0000e-04
# Epoch 18/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7541 - loss: 0.6773 - val_accuracy: 0.7610 - val_loss: 0.6514 - learning_rate: 5.0000e-04
# Epoch 19/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7604 - loss: 0.6393 - val_accuracy: 0.7688 - val_loss: 0.6454 - learning_rate: 5.0000e-04
# Epoch 20/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7697 - loss: 0.6201 - val_accuracy: 0.7584 - val_loss: 0.6419 - learning_rate: 5.0000e-04
# Epoch 21/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7635 - loss: 0.6309 - val_accuracy: 0.7481 - val_loss: 0.6452 - learning_rate: 5.0000e-04
# Epoch 22/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7635 - loss: 0.6001 - val_accuracy: 0.7636 - val_loss: 0.6363 - learning_rate: 5.0000e-04
# Epoch 23/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7604 - loss: 0.6160 - val_accuracy: 0.7662 - val_loss: 0.6367 - learning_rate: 5.0000e-04
# Epoch 24/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7759 - loss: 0.5979 - val_accuracy: 0.7636 - val_loss: 0.6410 - learning_rate: 5.0000e-04
# Epoch 25/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7811 - loss: 0.6060 - val_accuracy: 0.7636 - val_loss: 0.6393 - learning_rate: 5.0000e-04
# Epoch 26/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7759 - loss: 0.5921 - val_accuracy: 0.7610 - val_loss: 0.6389 - learning_rate: 2.5000e-04
# Epoch 27/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7707 - loss: 0.5845 - val_accuracy: 0.7714 - val_loss: 0.6313 - learning_rate: 2.5000e-04
# Epoch 28/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7666 - loss: 0.6039 - val_accuracy: 0.7740 - val_loss: 0.6327 - learning_rate: 2.5000e-04
# Epoch 29/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7863 - loss: 0.5747 - val_accuracy: 0.7688 - val_loss: 0.6337 - learning_rate: 2.5000e-04
# Epoch 30/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7739 - loss: 0.5923 - val_accuracy: 0.7714 - val_loss: 0.6307 - learning_rate: 2.5000e-04
# Epoch 31/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7687 - loss: 0.5900 - val_accuracy: 0.7740 - val_loss: 0.6305 - learning_rate: 2.5000e-04
# Epoch 32/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7790 - loss: 0.5865 - val_accuracy: 0.7714 - val_loss: 0.6320 - learning_rate: 2.5000e-04
# Epoch 33/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7842 - loss: 0.5814 - val_accuracy: 0.7688 - val_loss: 0.6331 - learning_rate: 2.5000e-04
# Epoch 34/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7780 - loss: 0.5560 - val_accuracy: 0.7714 - val_loss: 0.6338 - learning_rate: 2.5000e-04
# Epoch 35/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7801 - loss: 0.5565 - val_accuracy: 0.7688 - val_loss: 0.6360 - learning_rate: 1.2500e-04
# Epoch 36/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7967 - loss: 0.5628 - val_accuracy: 0.7688 - val_loss: 0.6340 - learning_rate: 1.2500e-04
# Epoch 37/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7853 - loss: 0.5774 - val_accuracy: 0.7662 - val_loss: 0.6326 - learning_rate: 1.2500e-04
# Epoch 38/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7749 - loss: 0.5740 - val_accuracy: 0.7662 - val_loss: 0.6326 - learning_rate: 6.2500e-05
# Epoch 39/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7863 - loss: 0.5776 - val_accuracy: 0.7714 - val_loss: 0.6330 - learning_rate: 6.2500e-05
# Epoch 40/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7728 - loss: 0.5812 - val_accuracy: 0.7714 - val_loss: 0.6325 - learning_rate: 6.2500e-05
# Epoch 41/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7780 - loss: 0.5735 - val_accuracy: 0.7688 - val_loss: 0.6320 - learning_rate: 3.1250e-05
# Epoch 42/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8008 - loss: 0.5410 - val_accuracy: 0.7688 - val_loss: 0.6317 - learning_rate: 3.1250e-05
# Epoch 43/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7801 - loss: 0.5570 - val_accuracy: 0.7688 - val_loss: 0.6315 - learning_rate: 3.1250e-05

# %%
import matplotlib.pyplot as plt


def plot_and_save_combined_history(hist, checkpoint_dir):
    acc = hist.history["accuracy"]
    val_acc = hist.history["val_accuracy"]

    epochs = range(1, len(acc) + 1)

    plt.plot(epochs, acc, label="training")
    plt.plot(epochs, val_acc, label="validation")
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(loc="upper left")

    plt.savefig(str(checkpoint_dir / 'training_history.png'))

    plt.show()


plot_and_save_combined_history(history, checkpoint_dir)

# %% [markdown]
# ## Evaluate Model

# %%
from keras.models import load_model

best_model = load_model(best_model_path)

# %%
val_loss, val_acc = best_model.evaluate(val_dataset)
print(f"Validation accuracy: {val_acc}\nValidation loss: {val_loss}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7740 - loss: 0.6305
# Validation accuracy: 0.7740259766578674
# Validation loss: 0.6305217742919922

# %%
test_loss, test_acc = best_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc}")
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6905 - loss: 1.0094
# Test accuracy: 0.6904761791229248

# %%
import numpy as np
from sklearn.metrics import classification_report

y_pred_vectors = best_model.predict(test_dataset)
y_pred = np.argmax(y_pred_vectors, axis=1)
y_true = np.concatenate([y for _, y in test_dataset], axis=0)

report = classification_report(y_true, y_pred, target_names=id_to_emotion.values(), digits=4)
print(report)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#               precision    recall  f1-score   support
#
#        Anger     0.7419    0.4259    0.5412        54
#      Disgust     0.4423    0.4259    0.4340        54
#         Fear     0.5641    0.4074    0.4731        54
#    Happiness     0.6709    0.9815    0.7970        54
#      Neutral     0.7143    0.8333    0.7692        54
#      Sadness     0.9592    0.8704    0.9126        54
#     Surprise     0.7385    0.8889    0.8067        54
#
#     accuracy                         0.6905       378
#    macro avg     0.6902    0.6905    0.6763       378
# weighted avg     0.6902    0.6905    0.6763       378

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns


def plot_confusion_matrix(y_true, y_pred):
    class_names = id_to_emotion.values()

    cm = confusion_matrix(y_true, y_pred)
    print(cm)

    fig = plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Class')
    plt.ylabel('Actual Class')
    plt.tight_layout()
    plt.show()

    return fig


cm_figure = plot_confusion_matrix(y_true, y_pred)
# Out:
# [[23 22  3  1  5  0  0]
#  [ 5 23  8 10  4  2  2]
#  [ 1  3 22  6  8  0 14]
#  [ 0  0  1 53  0  0  0]
#  [ 0  0  2  7 45  0  0]
#  [ 1  4  0  1  0 47  1]
#  [ 1  0  3  1  1  0 48]]

# %%
def save_evaluation_results(report, cm_figure, checkpoint_dir):
    with (checkpoint_dir / 'classification_report.txt').open(mode='w') as f:
        f.write(report)
    cm_figure.savefig(str(checkpoint_dir / 'confusion_matrix.png'))


save_evaluation_results(report, cm_figure, checkpoint_dir)

# %%
import time

time.sleep(5)

# %%
def add_test_acc_to_checkpoint_dir_name(checkpoint_dir, val_acc, test_acc):
    new_name = checkpoint_dir.name + f'_val_{str(val_acc)[2:6]}_test_{str(test_acc)[2:6]}'
    new_path = checkpoint_dir.parent / new_name
    checkpoint_dir.rename(new_path)
    return new_path


new_checkpoint_dir = add_test_acc_to_checkpoint_dir_name(checkpoint_dir, val_acc, test_acc)

# %%
time.sleep(5)

# %%
import shutil

shutil.copy2((Path() / name_of_this_notebook), (new_checkpoint_dir / name_of_this_notebook))
# Out:
# PosixPath('20260912-1907-checkpoint-lstm-mean-unoptimzed-b-32-lr-5e-04-seed-31_val_7740_test_6904/lstm-mean-unoptimzed.ipynb')
